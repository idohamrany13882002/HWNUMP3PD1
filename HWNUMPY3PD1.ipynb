# %%
# !pip install pandas
import pandas as pd
import numpy as np
from skimage import io
from PIL import Image

# %% [markdown]
# # exercise 1

# %%
np.random.seed (80)
arr_1 = np.random.randint(1,100,(4,4))
display (arr_1)
# Out:
# array([[48, 61, 39, 84],
#        [11, 51,  4, 87],
#        [24, 16, 82,  6],
#        [65, 10, 93, 43]])

# %% [markdown]
# ## question a

# %%
display(arr_1[arr_1>50])
# Out:
# array([61, 84, 51, 87, 82, 65, 93])

# %% [markdown]
# ## question b

# %%
display('columns:',arr_1.sum(0))
display('rows:',arr_1.sum(1))
# Out:
# 'columns:'
# array([148, 138, 218, 220])
# 'rows:'
# array([232, 153, 128, 211])

# %% [markdown]
# ## question c

# %%
display('max columns:',arr_1.max(0))
display('max rows:',arr_1.max(1))
display('min columns:',arr_1.min(0))
display('min rows:',arr_1.min(1))
display('avg columns:',arr_1.mean(0))
display('avg rows:',arr_1.mean(1))
# Out:
# 'max columns:'
# array([65, 61, 93, 87])
# 'max rows:'
# array([84, 87, 82, 93])
# 'min columns:'
# array([11, 10,  4,  6])
# 'min rows:'
# array([39,  4,  6, 10])
# 'avg columns:'
# array([37. , 34.5, 54.5, 55. ])
# 'avg rows:'
# array([58.  , 38.25, 32.  , 52.75])

# %% [markdown]
# # exercise 2

# %%
new_games = {
"Final Fantasy VII Rebirth": 69.99,
"Astro Bot": 59.99,
"Star Wars Outlaws": 69.99,
"Silent Hill 2 Remake": 69.99,
"Elden Ring: Shadow of the Erdtree": 39.99,
"Dragon Age: The Veilguard": 69.99,
"Metaphor: ReFantazio": 59.99
}
ser2 = pd.Series(data = new_games, index = new_games)
display(ser2)
# Out:
# Final Fantasy VII Rebirth            69.99
# Astro Bot                            59.99
# Star Wars Outlaws                    69.99
# Silent Hill 2 Remake                 69.99
# Elden Ring: Shadow of the Erdtree    39.99
# Dragon Age: The Veilguard            69.99
# Metaphor: ReFantazio                 59.99
# dtype: float64

# %% [markdown]
# ## question a

# %%
display(ser2["Metaphor: ReFantazio"])
# Out:
# 59.99

# %% [markdown]
# ## question b

# %%
display(ser2.index)
# Out:
# Index(['Final Fantasy VII Rebirth', 'Astro Bot', 'Star Wars Outlaws',
#        'Silent Hill 2 Remake', 'Elden Ring: Shadow of the Erdtree',
#        'Dragon Age: The Veilguard', 'Metaphor: ReFantazio'],
#       dtype='object')

# %% [markdown]
# ## question c

# %%
display(ser2[3])
# Out:
# /var/folders/m7/vz_v5_j10_l_yrgrgyqbqns40000gn/T/ipykernel_24863/4168716981.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   display(ser2[3])
# 69.99

# %% [markdown]
# ## question d

# %%
display(sum(ser2.values))
# Out:
# 439.93

# %% [markdown]
# # exercise 3

# %%
photo_1 = io.imread("jinny.jpg")
io.imshow(photo_1)

# %% [markdown]
# ## question a

# %%
display(photo_1.shape)
# Out:
# (222, 147, 3)

# %% [markdown]
# ## question b

# %%
io.imshow(photo_1[:,:50,:])

# %% [markdown]
# ## question c

# %%
photo_1_pil=Image.fromarray(photo_1)
display(photo_1_pil.rotate(120))
# Out:
# <PIL.Image.Image image mode=RGB size=147x222>
